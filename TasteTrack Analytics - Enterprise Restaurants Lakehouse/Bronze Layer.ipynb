# %%
# %sql
CREATE SCHEMA IF NOT EXISTS transactional_data;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE Transactional_Data.Employee
(
Employee_ID STRING       NOT NULL, 
Employee_Name STRING      NOT NULL,
Designation STRING       NOT NULL, 
Manager_ID STRING , 
Manager_Name STRING , 
Monthly_Salary DECIMAL(10,2)      NOT NULL,
Rating DECIMAL(10,2)      NOT NULL)
USING DELTA;

# %%
# %sql
select * from Transactional_Data.Employee;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
INSERT INTO transactional_data.employee
VALUES
('EMP001','Rahul Sharma','Restaurant Manager',NULL,NULL,85000.00,4.90),
('EMP002','Neha Verma','Assistant Manager','EMP001','Rahul Sharma',65000.00,4.70),
('EMP003','Amit Singh','Head Chef','EMP001','Rahul Sharma',70000.00,4.80),
('EMP004','Priya Kapoor','Chef','EMP003','Amit Singh',45000.00,4.60),
('EMP005','Rohit Mishra','Chef','EMP003','Amit Singh',43000.00,4.40),
('EMP006','Anjali Gupta','Senior Waiter','EMP002','Neha Verma',32000.00,4.70),
('EMP007','Vikas Yadav','Waiter','EMP006','Anjali Gupta',28000.00,4.50),
('EMP008','Sneha Tiwari','Waiter','EMP006','Anjali Gupta',29000.00,4.80),
('EMP009','Karan Malhotra','Delivery Coordinator','EMP002','Neha Verma',35000.00,4.60),
('EMP010','Riya Saxena','Cashier','EMP002','Neha Verma',30000.00,4.50);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
CREATE or replace TABLE Transactional_Data.STG_RESTAURANT_ORDERS
(
    RESTAURANT_ID                            INT   ,
RESTAURANT_NAME                          STRING     ,
SUBZONE                                 STRING     ,
CITY                                    STRING      ,

ORDER_ID                                BIGINT             ,
ORDER_PLACED_AT                         DATE      ,
ITEM_NAME                             STRING        ,
DISCOUNT_CONSTRUCT                      STRING    ,

BILL_SUBTOTAL                           DECIMAL(10,2) ,


RESTAURANT_DISCOUNT_PROMO               DECIMAL(10,2)       ,
RESTAURANT_DISCOUNT_FLAT_OFF            DECIMAL(10,2)       ,
GOLD_DISCOUNT                           DECIMAL(10,2)       ,
BRAND_PACK_DISCOUNT                     DECIMAL(10,2)      ,

TOTAL_AMOUNT                            DECIMAL(10,2)       ,

RATING                                  DECIMAL(2,1)      ,
REVIEW                                 STRING     ,

CANCELLATION_REJECTION_REASON           STRING   ,

RESTAURANT_COMPENSATION_CANCELLATION    DECIMAL(10,2)       ,
RESTAURANT_PENALTY_REJECTION            DECIMAL(10,2)       ,

CUSTOMER_COMPLAINT_TAG                  STRING     ,

CUSTOMER_ID                             STRING       ,
 QUANTITY					 				DECIMAL(10,2)       ,
WAITER_ID                            STRING     ,
CHEF_ID                             STRING       
)
using delta;

# %%
# %sql
INSERT INTO transactional_data.stg_restaurant_orders
VALUES
(101,'TasteTrack','Gomti Nagar','Lucknow',100001,'2026-07-01 13:15:00','Butter Chicken',NULL,850,50,0,20,0,780,4.8,'Excellent food',NULL,0,0,NULL,'CUST001',2,'EMP006','EMP004'),

(101,'TasteTrack','Gomti Nagar','Lucknow',100002,'2026-07-01 14:05:00','Paneer Tikka','Flat 10%',620,30,10,0,0,580,4.5,'Very tasty',NULL,0,0,NULL,'CUST002',1,'EMP007','EMP005'),

(102,'TasteTrack','Aliganj','Lucknow',100003,'2026-07-02 20:10:00','Veg Biryani',NULL,540,0,0,0,0,540,4.2,'Nice',NULL,0,0,NULL,'CUST003',2,'EMP008','EMP004'),

(103,'TasteTrack','Connaught Place','Delhi',100004,'2026-07-03 19:20:00','Chicken Pizza','Combo',950,100,50,20,30,750,4.9,'Amazing',NULL,0,0,NULL,'CUST001',1,'EMP006','EMP005'),

(104,'TasteTrack','Dwarka','Delhi',100005,'2026-07-04 21:15:00','Burger Meal',NULL,450,0,0,0,0,450,4.1,'Good',NULL,0,0,NULL,'CUST004',2,'EMP007','EMP004'),

(105,'TasteTrack','Sector 18','Noida',100006,'2026-07-05 18:45:00','Hakka Noodles',NULL,400,20,0,0,0,380,4.4,'Nice noodles',NULL,0,0,NULL,'CUST005',1,'EMP008','EMP005'),

(101,'TasteTrack','Gomti Nagar','Lucknow',100007,'2026-07-06 12:30:00','Chicken Biryani','Gold Offer',900,80,0,50,0,770,4.7,'Loved it',NULL,0,0,NULL,'CUST006',2,'EMP006','EMP004'),

(102,'TasteTrack','Aliganj','Lucknow',100008,'2026-07-07 15:00:00','Masala Dosa',NULL,300,0,0,0,0,300,4.0,'Crispy',NULL,0,0,NULL,'CUST007',1,'EMP007','EMP005'),

(103,'TasteTrack','Connaught Place','Delhi',100009,'2026-07-08 20:00:00','Pasta Alfredo',NULL,680,30,20,0,0,630,4.6,'Creamy pasta',NULL,0,0,NULL,'CUST008',2,'EMP008','EMP004'),

(104,'TasteTrack','Dwarka','Delhi',100010,'2026-07-09 13:45:00','Fish Curry',NULL,780,50,30,0,0,700,4.8,'Fresh fish',NULL,0,0,NULL,'CUST009',1,'EMP006','EMP005');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
select * from transactional_data.stg_restaurant_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE TABLE Transactional_Data.STG_RESTAURANT_ORDERS_ONLINE
(
    RESTAURANT_ID                            INT                 ,
    RESTAURANT_NAME                          string      ,
    SUBZONE                                 string      ,
    CITY                                   string       ,

    ORDER_ID                                BIGINT              ,
    ORDER_PLACED_AT                         DATE        ,
    ORDER_STATUS                            string     ,

    DELIVERY_PARTNER                       string       ,
    DISTANCE_KM                             DECIMAL(5,2)        ,

    ITEM_NAME                               string     ,

    INSTRUCTIONS                            string   ,
    DISCOUNT_CONSTRUCT                      string     ,

    BILL_SUBTOTAL                           DECIMAL(10,2)       ,
    PACKAGING_CHARGES                       DECIMAL(10,2)       ,

    RESTAURANT_DISCOUNT_PROMO               DECIMAL(10,2)       ,
    RESTAURANT_DISCOUNT_FLAT_OFF            DECIMAL(10,2)       ,
    GOLD_DISCOUNT                           DECIMAL(10,2)       ,
    BRAND_PACK_DISCOUNT                     DECIMAL(10,2)       ,

    TOTAL_AMOUNT                            DECIMAL(10,2)       ,

    RATING                                  DECIMAL(2,1)        ,
    REVIEW                                  string,

    CANCELLATION_REJECTION_REASON           string     ,

    RESTAURANT_COMPENSATION_CANCELLATION    DECIMAL(10,2)       ,
    RESTAURANT_PENALTY_REJECTION            DECIMAL(10,2)       ,

    KPT_DURATION_MINUTES                    DECIMAL(6,2)        ,
    RIDER_WAIT_TIME_MINUTES                 DECIMAL(6,2)        ,

    ORDER_READY_MARKED                      string     ,

    CUSTOMER_COMPLAINT_TAG                  string      ,

    CUSTOMER_ID                             string   ,
     QUANTITY					 				DECIMAL(10,2)       
   
);

# %%
# %sql
INSERT INTO Transactional_Data.STG_RESTAURANT_ORDERS_ONLINE
(
RESTAURANT_ID,
RESTAURANT_NAME,
SUBZONE,
CITY,
ORDER_ID,
ORDER_PLACED_AT,
ORDER_STATUS,
DELIVERY_PARTNER,
DISTANCE_KM,
ITEM_NAME,
INSTRUCTIONS,
DISCOUNT_CONSTRUCT,
BILL_SUBTOTAL,
PACKAGING_CHARGES,
RESTAURANT_DISCOUNT_PROMO,
RESTAURANT_DISCOUNT_FLAT_OFF,
GOLD_DISCOUNT,
BRAND_PACK_DISCOUNT,
TOTAL_AMOUNT,
RATING,
REVIEW,
CANCELLATION_REJECTION_REASON,
RESTAURANT_COMPENSATION_CANCELLATION,
RESTAURANT_PENALTY_REJECTION,
KPT_DURATION_MINUTES,
RIDER_WAIT_TIME_MINUTES,
ORDER_READY_MARKED,
CUSTOMER_COMPLAINT_TAG,
CUSTOMER_ID,
QUANTITY
)
VALUES
(101,'TasteTrack','Gomti Nagar','Lucknow',200001,'2026-07-01','Delivered','Zomato',5.40,'Butter Chicken','Less spicy',NULL,850,30,20,0,0,0,860,4.8,'Hot and delicious',NULL,0,0,35,5,'Yes',NULL,'CUST010',2),

(102,'TasteTrack','Aliganj','Lucknow',200002,'2026-07-02','Delivered','Swiggy',3.20,'Veg Biryani',NULL,'Flat ₹50',620,25,50,0,0,0,595,4.5,'Good packing',NULL,0,0,30,4,'Yes',NULL,'CUST011',1),

(103,'TasteTrack','Connaught Place','Delhi',200003,'2026-07-03','Cancelled','Zomato',7.50,'Chicken Pizza',NULL,NULL,950,40,0,0,0,0,990,NULL,NULL,'Restaurant Closed',120,0,NULL,NULL,NULL,NULL,'CUST012',1),

(104,'TasteTrack','Dwarka','Delhi',200004,'2026-07-04','Delivered','Swiggy',2.50,'Burger Meal','Extra ketchup',NULL,450,20,0,0,0,0,470,4.1,'Quick delivery',NULL,0,0,22,3,'Yes',NULL,'CUST013',2),

(105,'TasteTrack','Sector 18','Noida',200005,'2026-07-05','Delivered','Blinkit',4.10,'Pasta Alfredo',NULL,NULL,700,30,20,10,0,0,700,4.7,'Loved it',NULL,0,0,28,2,'Yes',NULL,'CUST014',1),

(101,'TasteTrack','Gomti Nagar','Lucknow',200006,'2026-07-06','Rejected','Zomato',6.00,'Chicken Biryani',NULL,NULL,850,25,0,0,0,0,875,NULL,NULL,'Restaurant Busy',0,80,NULL,NULL,NULL,NULL,'CUST015',2),

(102,'TasteTrack','Aliganj','Lucknow',200007,'2026-07-07','Delivered','Swiggy',3.70,'Masala Dosa',NULL,NULL,300,15,0,0,0,0,315,4.0,'Good',NULL,0,0,18,1,'Yes',NULL,'CUST016',1),

(103,'TasteTrack','Connaught Place','Delhi',200008,'2026-07-08','Delivered','Zomato',8.20,'Fish Curry','No onions','Gold Offer',820,35,30,20,0,0,805,4.9,'Excellent',NULL,0,0,40,6,'Yes',NULL,'CUST017',2),

(104,'TasteTrack','Dwarka','Delhi',200009,'2026-07-09','Delivered','Blinkit',2.90,'Paneer Tikka',NULL,NULL,500,20,0,0,0,0,520,4.3,'Nice',NULL,0,0,25,3,'Yes',NULL,'CUST018',1),

(105,'TasteTrack','Sector 18','Noida',200010,'2026-07-10','Delivered','Swiggy',5.00,'Hakka Noodles','Extra spicy',NULL,420,20,20,0,0,0,420,4.6,'Very tasty',NULL,0,0,26,4,'Yes',NULL,'CUST019',2);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
select * from Transactional_Data.STG_RESTAURANT_ORDERS_ONLINE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
